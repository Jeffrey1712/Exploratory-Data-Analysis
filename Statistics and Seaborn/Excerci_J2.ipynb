# %%
# !pip3 install numpy

# %% [markdown]
# ### Scatterplots 🎄

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("src/house_pricing.csv")

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
dataset.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
sns.relplot(x="SalePrice", y="LotArea", data=dataset)

# %%
sns.relplot(x="LotArea", y="SalePrice",
            data=dataset[(dataset.LotArea < 20000) & (dataset.SalePrice < 500000)])

# %%
sns.relplot(x="LotFrontage", y="LotArea", data=dataset)

# %%
sns.relplot(x="LotFrontage", y="LotArea", data=dataset[(dataset.LotFrontage < 200) & (dataset.LotArea < 100000)])

# %% [markdown]
# ### Heatmaps 🔥

# %%
dataset = pd.read_csv("src/house_pricing2.csv")
dataset = dataset.iloc[:,-15:]
dataset.head()
# Out:
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0           0           61              0          0            0         0
# 1         298            0              0          0            0         0
# 2           0           42              0          0            0         0
# 3           0           35            272          0            0         0
# 4         192           84              0          0            0         0
#
#   PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# 0    NaN   NaN         NaN        0       2    2008       WD        Normal
# 1    NaN   NaN         NaN        0       5    2007       WD        Normal
# 2    NaN   NaN         NaN        0       9    2008       WD        Normal
# 3    NaN   NaN         NaN        0       2    2006       WD       Abnorml
# 4    NaN   NaN         NaN        0      12    2008       WD        Normal
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# ...

# %%
dataset.describe(include='all')
# Out:
#          WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count   1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# unique          NaN          NaN            NaN          NaN          NaN
# top             NaN          NaN            NaN          NaN          NaN
# freq            NaN          NaN            NaN          NaN          NaN
# mean      94.244521    46.660274      21.954110     3.409589    15.060959
# std      125.338794    66.256028      61.119149    29.317331    55.757415
# min        0.000000     0.000000       0.000000     0.000000     0.000000
# 25%        0.000000     0.000000       0.000000     0.000000     0.000000
# 50%        0.000000    25.000000       0.000000     0.000000     0.000000
# 75%      168.000000    68.000000       0.000000     0.000000     0.000000
# max      857.000000   547.000000     552.000000   508.000000   480.000000
#
#            PoolArea PoolQC  Fence MiscFeature       MiscVal       MoSold  \
# ...

# %%
dataset.describe() # pour garder que les colonnes numériques
# Out:
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# ...

# %%
new_cols = ["WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch", "PoolArea", "MiscVal", "MoSold", "YrSold", "SalePrice"]
dataset = dataset[new_cols]
dataset
# Out:
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea  MiscVal  MoSold  YrSold  SalePrice
# 0            0        0       2    2008     208500
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   WoodDeckSF     1460 non-null   int64
#  1   OpenPorchSF    1460 non-null   int64
#  2   EnclosedPorch  1460 non-null   int64
#  3   3SsnPorch      1460 non-null   int64
#  4   ScreenPorch    1460 non-null   int64
#  5   PoolArea       1460 non-null   int64
#  6   MiscVal        1460 non-null   int64
#  7   MoSold         1460 non-null   int64
#  8   YrSold         1460 non-null   int64
#  9   SalePrice      1460 non-null   int64
# dtypes: int64(10)
# memory usage: 114.2 KB

# %%
correlation = dataset.corr()
correlation
# Out:
#                WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# WoodDeckSF       1.000000     0.058661      -0.125989  -0.032771    -0.074181
# OpenPorchSF      0.058661     1.000000      -0.093079  -0.005842     0.074304
# EnclosedPorch   -0.125989    -0.093079       1.000000  -0.037305    -0.082864
# 3SsnPorch       -0.032771    -0.005842      -0.037305   1.000000    -0.031436
# ScreenPorch     -0.074181     0.074304      -0.082864  -0.031436     1.000000
# PoolArea         0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal         -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold           0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold           0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice        0.324413     0.315856      -0.128578   0.044584     0.111447
#
#                PoolArea   MiscVal    MoSold    YrSold  SalePrice
# ...

# %%
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
abs(correlation['SalePrice']).sort_values(ascending = False)
# Out:
# SalePrice        1.000000
# WoodDeckSF       0.324413
# OpenPorchSF      0.315856
# EnclosedPorch    0.128578
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# YrSold           0.028923
# MiscVal          0.021190
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### Linear relationships 📈

# %%
dataset = pd.read_csv("src/IBM_HR_ATTRITION.csv")

# %%
dataset.tail(5)
# pour voir les 5 dernières lignes tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
dataset["Attrition"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
dataset["Attrition"].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
dataset['Attrition'] = dataset['Attrition'].apply(lambda x: 1 if x ()=="Yes" else 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 dataset['Attrition'] = dataset['Attrition'].apply(lambda x: 1 if x ()=="Yes" else 0)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:4904, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)
#    4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)
#    4895     dtype: float64
#    4896     """
#    4897     return SeriesApply(
#    4898         self,
#    4899         func,
#    4900         convert_dtype=convert_dtype,
#    4901         by_row=by_row,
#    4902         args=args,
#    4903         kwargs=kwargs,
# -> 4904     ).apply()
#
# ...

# %%
sns.lmplot(x="DistanceFromHome", y="Attrition", data= dataset, logistic = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 sns.lmplot(x="DistanceFromHome", y="Attrition", data= dataset, logistic = True)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/regression.py:640, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     637     ax.update_datalim(xys, updatey=False)
#     638     ax.autoscale_view(scaley=False)
# --> 640 facets.map_dataframe(update_datalim, x=x, y=y)
#     642 # Draw the regression plot on each facet
#     643 regplot_kws = dict(
# ...
